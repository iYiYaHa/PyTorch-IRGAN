# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter

import time

from model import Discriminator
from config import irgan_config
from data_utils import RecDataset, DataProvider
from evaluation.rec_evaluator import RecEvaluator

# %%
epochs = irgan_config.epochs
batch_size = irgan_config.batch_size
epochs_d = irgan_config.epochs_d
emb_dim = irgan_config.emb_dim
eta_D = irgan_config.eta_D
device = irgan_config.device
weight_decay_d = irgan_config.weight_decay_d
patience = irgan_config.patience

# %%
# Hyper-parameters and datset-specific parameters
rec_dataset = RecDataset(irgan_config.dir_path)
all_users = rec_dataset.get_users()
all_items = rec_dataset.get_items()
num_users = rec_dataset.get_num_users()
num_items = rec_dataset.get_num_items()
bought_mask = rec_dataset.get_bought_mask().to(device)
bought_dict = rec_dataset.get_interaction_records()
eval_dict = rec_dataset.get_interaction_records("test")
train_ui = rec_dataset.get_user_item_pairs()

# %%
dp = DataProvider(device)
evaluator = RecEvaluator(eval_dict, None, device)

# %%
writer = SummaryWriter("runs/Pretrained-discriminator-Dynamic-Negative-Sampling-SGD-momentum-dim-5")

# %%
D = Discriminator(num_users, num_items, emb_dim,bought_mask)
D = D.to(device)
loss_D = nn.BCELoss()
optimizer_D = torch.optim.SGD(D.parameters(), lr = eta_D, momentum = 0.9, weight_decay = weight_decay_d)

# %%
train_set = dp.prepare_bpr_triplets_dns(D, bought_mask)

# %%
bad_counter = 0
best_epoch = 0
best_p = 0

for epoch in range(epochs):
    time_start = time.time()
    loss_epoch = 0
    train_set = dp.prepare_bpr_triplets_dns(D, bought_mask) # Dynamic Negative Sampling
    for users, pos_items, neg_items in train_set:
        x_ui = D(users,pos_items)
        x_uj = D(users,neg_items)
        
        x_uij = x_ui - x_uj
        loss = -torch.log(torch.sigmoid(x_uij)).mean()
        loss_epoch += loss.item()
        optimizer_D.zero_grad()
        loss.backward()
        optimizer_D.step()
            
    time_end = time.time()
    loss_epoch /= len(train_set)
    print(
        "\t[Discriminator][Epochs %d/%d] [D epoch loss: %6.5f] [Time:%6.5f] "
        % (epoch+1, epochs, loss_epoch, time_end - time_start)
    )
    writer.add_scalar('Loss', loss_epoch, epoch)
    
    with torch.no_grad():
        res = evaluator.top_k_evaluation(D, [3,5,10])    
        ndcg3, precision3, hit3, map3, mrr3 = res[0]
        ndcg5, precision5, hit5, map5, mrr5 = res[1]
        ndcg10, precision10, hit10, map10, mrr10 = res[2]
        writer.add_scalar('Metrics/NDCG@3', ndcg3, epoch)
        writer.add_scalar('Metrics/NDCG@5', ndcg5, epoch)
        writer.add_scalar('Metrics/NDCG@10', ndcg10, epoch)
        writer.add_scalar('Metrics/Precision@3', precision3, epoch)
        writer.add_scalar('Metrics/Precision@5', precision5, epoch)
        writer.add_scalar('Metrics/Precision@10', precision10, epoch)
        writer.add_scalar('Metrics/Hit@3', hit3, epoch)
        writer.add_scalar('Metrics/Hit@5', hit5, epoch)
        writer.add_scalar('Metrics/Hit@10', hit10, epoch)
        writer.add_scalar('Metrics/MAP', map10, epoch)
        writer.add_scalar('Metrics/MRR', mrr10, epoch)
        
        if(precision10 > best_p):
            best_p = precision10
            best_epoch = epoch
            bad_counter = 0
            torch.save(D.state_dict(), "./pretrained_models/pretrained_model_dns.pkl")
        else:
            bad_counter += 1   
            
        if bad_counter == patience:
            break
    time_epoch_end = time.time()
writer.close()
# Out:
# 	[Discriminator][Epochs 1/200] [D epoch loss: 0.69337] [Time:2.91622]
# 	[Discriminator][Epochs 2/200] [D epoch loss: 0.69327] [Time:3.31816]
# 	[Discriminator][Epochs 3/200] [D epoch loss: 0.69321] [Time:3.31159]
# 	[Discriminator][Epochs 4/200] [D epoch loss: 0.69316] [Time:3.18577]
# 	[Discriminator][Epochs 5/200] [D epoch loss: 0.69313] [Time:3.19791]
# 	[Discriminator][Epochs 6/200] [D epoch loss: 0.69308] [Time:3.22016]
# 	[Discriminator][Epochs 7/200] [D epoch loss: 0.69304] [Time:3.08630]
# 	[Discriminator][Epochs 8/200] [D epoch loss: 0.69301] [Time:3.11124]
# 	[Discriminator][Epochs 9/200] [D epoch loss: 0.69296] [Time:3.27186]
# 	[Discriminator][Epochs 10/200] [D epoch loss: 0.69292] [Time:3.30709]
# 	[Discriminator][Epochs 11/200] [D epoch loss: 0.69289] [Time:3.13292]
# 	[Discriminator][Epochs 12/200] [D epoch loss: 0.69286] [Time:3.09041]
# 	[Discriminator][Epochs 13/200] [D epoch loss: 0.69282] [Time:3.17283]
# 	[Discriminator][Epochs 14/200] [D epoch loss: 0.69273] [Time:3.05295]
# 	[Discriminator][Epochs 15/200] [D epoch loss: 0.69270] [Time:3.00426]
# 	[Discriminator][Epochs 16/200] [D epoch loss: 0.69261] [Time:3.06292]
# 	[Discriminator][Epochs 17/200] [D epoch loss: 0.69260] [Time:3.20138]
# 	[Discriminator][Epochs 18/200] [D epoch loss: 0.69258] [Time:3.27443]
# 	[Discriminator][Epochs 19/200] [D epoch loss: 0.69261] [Time:3.33926]
# 	[Discriminator][Epochs 20/200] [D epoch loss: 0.69257] [Time:3.15847]
# 	[Discriminator][Epochs 21/200] [D epoch loss: 0.69243] [Time:3.05733]
# 	[Discriminator][Epochs 22/200] [D epoch loss: 0.69240] [Time:3.04868]
# 	[Discriminator][Epochs 23/200] [D epoch loss: 0.69240] [Time:3.07383]
# 	[Discriminator][Epochs 24/200] [D epoch loss: 0.69235] [Time:2.98724]
# 	[Discriminator][Epochs 25/200] [D epoch loss: 0.69235] [Time:3.04865]
# 	[Discriminator][Epochs 26/200] [D epoch loss: 0.69227] [Time:3.21523]
# 	[Discriminator][Epochs 27/200] [D epoch loss: 0.69227] [Time:3.30289]
# 	[Discriminator][Epochs 28/200] [D epoch loss: 0.69220] [Time:3.30356]
# 	[Discriminator][Epochs 29/200] [D epoch loss: 0.69213] [Time:2.94214]
# 	[Discriminator][Epochs 30/200] [D epoch loss: 0.69209] [Time:3.14091]
# 	[Discriminator][Epochs 168/200] [D epoch loss: 0.68747] [Time:2.63433]
# 	[Discriminator][Epochs 169/200] [D epoch loss: 0.68735] [Time:2.63178]
# 	[Discriminator][Epochs 170/200] [D epoch loss: 0.68732] [Time:2.64760]
# 	[Discriminator][Epochs 171/200] [D epoch loss: 0.68745] [Time:2.55382]
# 	[Discriminator][Epochs 172/200] [D epoch loss: 0.68754] [Time:2.89056]
# 	[Discriminator][Epochs 173/200] [D epoch loss: 0.68728] [Time:3.17774]
# 	[Discriminator][Epochs 174/200] [D epoch loss: 0.68748] [Time:3.26243]
# 	[Discriminator][Epochs 175/200] [D epoch loss: 0.68717] [Time:3.11374]
# 	[Discriminator][Epochs 176/200] [D epoch loss: 0.68744] [Time:3.18742]
# 	[Discriminator][Epochs 177/200] [D epoch loss: 0.68745] [Time:3.13939]
# 	[Discriminator][Epochs 178/200] [D epoch loss: 0.68762] [Time:3.23312]
# 	[Discriminator][Epochs 179/200] [D epoch loss: 0.68749] [Time:2.92640]
# 	[Discriminator][Epochs 180/200] [D epoch loss: 0.68743] [Time:3.10313]
# 	[Discriminator][Epochs 181/200] [D epoch loss: 0.68697] [Time:3.21926]
# 	[Discriminator][Epochs 182/200] [D epoch loss: 0.68704] [Time:3.26639]
# 	[Discriminator][Epochs 183/200] [D epoch loss: 0.68725] [Time:3.22242]
# 	[Discriminator][Epochs 184/200] [D epoch loss: 0.68691] [Time:3.22283]
# 	[Discriminator][Epochs 185/200] [D epoch loss: 0.68720] [Time:3.19993]
# 	[Discriminator][Epochs 186/200] [D epoch loss: 0.68706] [Time:3.17539]
# 	[Discriminator][Epochs 187/200] [D epoch loss: 0.68652] [Time:3.08661]
# 	[Discriminator][Epochs 188/200] [D epoch loss: 0.68702] [Time:3.19004]
# 	[Discriminator][Epochs 189/200] [D epoch loss: 0.68690] [Time:3.08642]
# 	[Discriminator][Epochs 190/200] [D epoch loss: 0.68641] [Time:2.83281]
# 	[Discriminator][Epochs 191/200] [D epoch loss: 0.68673] [Time:3.20854]
# 	[Discriminator][Epochs 192/200] [D epoch loss: 0.68669] [Time:3.06419]
# 	[Discriminator][Epochs 193/200] [D epoch loss: 0.68682] [Time:3.23491]
# 	[Discriminator][Epochs 194/200] [D epoch loss: 0.68667] [Time:2.93965]
# 	[Discriminator][Epochs 195/200] [D epoch loss: 0.68647] [Time:3.08646]
# 	[Discriminator][Epochs 196/200] [D epoch loss: 0.68632] [Time:3.12992]
# 	[Discriminator][Epochs 197/200] [D epoch loss: 0.68631] [Time:3.15294]
# 	[Discriminator][Epochs 198/200] [D epoch loss: 0.68632] [Time:2.93713]
# 	[Discriminator][Epochs 199/200] [D epoch loss: 0.68655] [Time:2.98074]
# 	[Discriminator][Epochs 200/200] [D epoch loss: 0.68691] [Time:2.75357]

# %%
print(best_epoch)
D.load_state_dict(torch.load("./pretrained_models/pretrained_model_dns.pkl"))
# Out:
# 198
# <All keys matched successfully>
