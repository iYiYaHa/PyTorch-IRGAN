# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter

import time

from model import Discriminator
from config import irgan_config
from data_utils import RecDataset, DataProvider
from evaluation.rec_evaluator import RecEvaluator

# %%
epochs = irgan_config.epochs
batch_size = irgan_config.batch_size
epochs_d = irgan_config.epochs_d
emb_dim = irgan_config.emb_dim
eta_D = irgan_config.eta_D
device = irgan_config.device
weight_decay_d = irgan_config.weight_decay_d
patience = irgan_config.patience

# %%
# Hyper-parameters and datset-specific parameters
rec_dataset = RecDataset(irgan_config.dir_path)
all_users = rec_dataset.get_users()
all_items = rec_dataset.get_items()
num_users = rec_dataset.get_num_users()
num_items = rec_dataset.get_num_items()
bought_mask = rec_dataset.get_bought_mask().to(device)
bought_dict = rec_dataset.get_interaction_records()
eval_dict = rec_dataset.get_interaction_records("test")
train_ui = rec_dataset.get_user_item_pairs()

# %%
dp = DataProvider(device)
evaluator = RecEvaluator(eval_dict, None, device)

# %%
writer = SummaryWriter("runs/Pretrained-discriminator-Dynamic-Negative-Sampling-Adam-dim-5")

# %%
D = Discriminator(num_users, num_items, emb_dim,bought_mask)
D = D.to(device)
loss_D = nn.BCELoss()
optimizer_D = torch.optim.Adam(D.parameters(), lr = eta_D, weight_decay = weight_decay_d)

# %%
train_set = dp.prepare_bpr_triplets_dns(D, bought_mask)

# %%
bad_counter = 0
best_epoch = 0
best_p = 0

for epoch in range(epochs):
    time_start = time.time()
    loss_epoch = 0
    train_set = dp.prepare_bpr_triplets_dns(D, bought_mask) # Dynamic Negative Sampling
    for users, pos_items, neg_items in train_set:
        x_ui = D(users,pos_items)
        x_uj = D(users,neg_items)
        
        x_uij = x_ui - x_uj
        loss = -torch.log(torch.sigmoid(x_uij)).mean()
        loss_epoch += loss.item()
        optimizer_D.zero_grad()
        loss.backward()
        optimizer_D.step()
            
    time_end = time.time()
    loss_epoch /= len(train_set)
    print(
        "\t[Discriminator][Epochs %d/%d] [D epoch loss: %6.5f] [Time:%6.5f] "
        % (epoch+1, epochs, loss_epoch, time_end - time_start)
    )
    writer.add_scalar('Loss', loss_epoch, epoch)
    
    with torch.no_grad():
        res = evaluator.top_k_evaluation(D, [3,5,10])    
        ndcg3, precision3, hit3, map3, mrr3 = res[0]
        ndcg5, precision5, hit5, map5, mrr5 = res[1]
        ndcg10, precision10, hit10, map10, mrr10 = res[2]
        writer.add_scalar('Metrics/NDCG@3', ndcg3, epoch)
        writer.add_scalar('Metrics/NDCG@5', ndcg5, epoch)
        writer.add_scalar('Metrics/NDCG@10', ndcg10, epoch)
        writer.add_scalar('Metrics/Precision@3', precision3, epoch)
        writer.add_scalar('Metrics/Precision@5', precision5, epoch)
        writer.add_scalar('Metrics/Precision@10', precision10, epoch)
        writer.add_scalar('Metrics/Hit@3', hit3, epoch)
        writer.add_scalar('Metrics/Hit@5', hit5, epoch)
        writer.add_scalar('Metrics/Hit@10', hit10, epoch)
        writer.add_scalar('Metrics/MAP', map10, epoch)
        writer.add_scalar('Metrics/MRR', mrr10, epoch)
        
        if(precision10 > best_p):
            best_p = precision10
            best_epoch = epoch
            bad_counter = 0
            torch.save(D.state_dict(),"./pretrained_models/pretrained_model_dns_adam.pkl")
        else:
            bad_counter += 1   
            
        if bad_counter == patience:
            break
    time_epoch_end = time.time()
writer.close()
# Out:
# 	[Discriminator][Epochs 1/200] [D epoch loss: 0.68240] [Time:3.26899]
# 	[Discriminator][Epochs 2/200] [D epoch loss: 0.68833] [Time:3.31623]
# 	[Discriminator][Epochs 3/200] [D epoch loss: 0.68192] [Time:3.62677]
# 	[Discriminator][Epochs 4/200] [D epoch loss: 0.68030] [Time:3.47572]
# 	[Discriminator][Epochs 5/200] [D epoch loss: 0.67551] [Time:3.53227]
# 	[Discriminator][Epochs 6/200] [D epoch loss: 0.67670] [Time:3.57712]
# 	[Discriminator][Epochs 7/200] [D epoch loss: 0.67357] [Time:3.53698]
# 	[Discriminator][Epochs 8/200] [D epoch loss: 0.67270] [Time:3.43919]
# 	[Discriminator][Epochs 9/200] [D epoch loss: 0.66818] [Time:3.50079]
# 	[Discriminator][Epochs 10/200] [D epoch loss: 0.66583] [Time:3.71564]
# 	[Discriminator][Epochs 11/200] [D epoch loss: 0.66233] [Time:3.62580]
# 	[Discriminator][Epochs 12/200] [D epoch loss: 0.66169] [Time:3.44095]
# 	[Discriminator][Epochs 13/200] [D epoch loss: 0.66008] [Time:3.60311]
# 	[Discriminator][Epochs 14/200] [D epoch loss: 0.65838] [Time:3.60291]
# 	[Discriminator][Epochs 15/200] [D epoch loss: 0.65419] [Time:3.57068]
# 	[Discriminator][Epochs 16/200] [D epoch loss: 0.65652] [Time:3.33722]
# 	[Discriminator][Epochs 17/200] [D epoch loss: 0.65420] [Time:3.58540]
# 	[Discriminator][Epochs 18/200] [D epoch loss: 0.65055] [Time:3.72966]
# 	[Discriminator][Epochs 19/200] [D epoch loss: 0.65093] [Time:3.69819]
# 	[Discriminator][Epochs 20/200] [D epoch loss: 0.64977] [Time:3.59214]
# 	[Discriminator][Epochs 21/200] [D epoch loss: 0.64713] [Time:3.60616]
# 	[Discriminator][Epochs 22/200] [D epoch loss: 0.64551] [Time:3.58931]
# 	[Discriminator][Epochs 23/200] [D epoch loss: 0.64625] [Time:3.53196]
# 	[Discriminator][Epochs 24/200] [D epoch loss: 0.64485] [Time:3.30660]
# 	[Discriminator][Epochs 25/200] [D epoch loss: 0.64550] [Time:3.62492]
# 	[Discriminator][Epochs 26/200] [D epoch loss: 0.64274] [Time:3.72875]
# 	[Discriminator][Epochs 27/200] [D epoch loss: 0.64012] [Time:3.53670]
# 	[Discriminator][Epochs 28/200] [D epoch loss: 0.64102] [Time:3.60925]
# 	[Discriminator][Epochs 29/200] [D epoch loss: 0.64053] [Time:3.63372]
# 	[Discriminator][Epochs 30/200] [D epoch loss: 0.64002] [Time:3.62649]
# 	[Discriminator][Epochs 168/200] [D epoch loss: 0.60602] [Time:3.46020]
# 	[Discriminator][Epochs 169/200] [D epoch loss: 0.60296] [Time:3.27379]
# 	[Discriminator][Epochs 170/200] [D epoch loss: 0.60629] [Time:3.35102]
# 	[Discriminator][Epochs 171/200] [D epoch loss: 0.60444] [Time:3.26514]
# 	[Discriminator][Epochs 172/200] [D epoch loss: 0.60651] [Time:3.28026]
# 	[Discriminator][Epochs 173/200] [D epoch loss: 0.60567] [Time:3.34152]
# 	[Discriminator][Epochs 174/200] [D epoch loss: 0.60644] [Time:3.26731]
# 	[Discriminator][Epochs 175/200] [D epoch loss: 0.60534] [Time:3.47092]
# 	[Discriminator][Epochs 176/200] [D epoch loss: 0.60566] [Time:3.53768]
# 	[Discriminator][Epochs 177/200] [D epoch loss: 0.60465] [Time:3.67761]
# 	[Discriminator][Epochs 178/200] [D epoch loss: 0.60611] [Time:3.77133]
# 	[Discriminator][Epochs 179/200] [D epoch loss: 0.60419] [Time:3.12417]
# 	[Discriminator][Epochs 180/200] [D epoch loss: 0.60244] [Time:3.81955]
# 	[Discriminator][Epochs 181/200] [D epoch loss: 0.60497] [Time:3.20355]
# 	[Discriminator][Epochs 182/200] [D epoch loss: 0.60405] [Time:3.15343]
# 	[Discriminator][Epochs 183/200] [D epoch loss: 0.60413] [Time:3.37913]
# 	[Discriminator][Epochs 184/200] [D epoch loss: 0.60676] [Time:3.06607]
# 	[Discriminator][Epochs 185/200] [D epoch loss: 0.60802] [Time:3.14182]
# 	[Discriminator][Epochs 186/200] [D epoch loss: 0.60296] [Time:3.07499]
# 	[Discriminator][Epochs 187/200] [D epoch loss: 0.60721] [Time:3.94005]
# 	[Discriminator][Epochs 188/200] [D epoch loss: 0.60485] [Time:3.21507]
# 	[Discriminator][Epochs 189/200] [D epoch loss: 0.60559] [Time:3.07343]
# 	[Discriminator][Epochs 190/200] [D epoch loss: 0.60705] [Time:3.14169]
# 	[Discriminator][Epochs 191/200] [D epoch loss: 0.60758] [Time:3.06108]
# 	[Discriminator][Epochs 192/200] [D epoch loss: 0.60571] [Time:3.74186]
# 	[Discriminator][Epochs 193/200] [D epoch loss: 0.60640] [Time:3.94375]
# 	[Discriminator][Epochs 194/200] [D epoch loss: 0.60439] [Time:3.92616]
# 	[Discriminator][Epochs 195/200] [D epoch loss: 0.60401] [Time:3.15260]
# 	[Discriminator][Epochs 196/200] [D epoch loss: 0.60834] [Time:3.16199]
# 	[Discriminator][Epochs 197/200] [D epoch loss: 0.60266] [Time:3.06635]
# 	[Discriminator][Epochs 198/200] [D epoch loss: 0.60534] [Time:3.06943]
# 	[Discriminator][Epochs 199/200] [D epoch loss: 0.60358] [Time:3.14351]
# 	[Discriminator][Epochs 200/200] [D epoch loss: 0.60482] [Time:3.47236]

# %%
print(best_epoch)
D.load_state_dict(torch.load("./pretrained_models/pretrained_model_dns_adam.pkl"))
# Out:
# 183
# <All keys matched successfully>
