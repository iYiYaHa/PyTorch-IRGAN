# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter

import time

from model import Discriminator
from config import irgan_config
from data_utils import RecDataset, DataProvider
from evaluation.rec_evaluator import RecEvaluator

# %%
epochs = irgan_config.epochs
batch_size = irgan_config.batch_size
epochs_d = irgan_config.epochs_d
emb_dim = irgan_config.emb_dim
eta_D = irgan_config.eta_D
device = irgan_config.device
weight_decay_d = irgan_config.weight_decay_d
patience = irgan_config.patience

# %%
# Hyper-parameters and datset-specific parameters
rec_dataset = RecDataset(irgan_config.dir_path)
all_users = rec_dataset.get_users()
all_items = rec_dataset.get_items()
num_users = rec_dataset.get_num_users()
num_items = rec_dataset.get_num_items()
bought_mask = rec_dataset.get_bought_mask().to(device)
bought_dict = rec_dataset.get_interaction_records()
eval_dict = rec_dataset.get_interaction_records("test")
train_ui = rec_dataset.get_user_item_pairs()

# %%
dp = DataProvider(device)
evaluator = RecEvaluator(eval_dict, None, device)

# %%
writer = SummaryWriter("runs/Pretrained-discriminator-Static-Negative-Sampling")

# %%
D = Discriminator(num_users, num_items, emb_dim,bought_mask)
D = D.to(device)
loss_D = nn.BCELoss()
optimizer_D = torch.optim.Adam(D.parameters(), lr = eta_D, weight_decay = weight_decay_d)

# %%
train_set = dp.prepare_bpr_triplets_dns(D, bought_mask)

# %%
bad_counter = 0
best_epoch = 0
best_p = 0

for epoch in range(epochs):
    time_start = time.time()
    loss_epoch = 0
    train_set = dp.prepare_bpr_triplets(all_items,bought_dict) # Static Negative Sampling
    for users, pos_items, neg_items in train_set:
        x_ui = D(users,pos_items)
        x_uj = D(users,neg_items)
        
        x_uij = x_ui - x_uj
        loss = -torch.log(torch.sigmoid(x_uij)).mean()
        loss_epoch += loss.item()
        optimizer_D.zero_grad()
        loss.backward()
        optimizer_D.step()
            
    time_end = time.time()
    loss_epoch /= len(train_set)
    print(
        "\t[Discriminator][Epochs %d/%d] [D epoch loss: %6.5f] [Time:%6.5f] "
        % (epoch+1, epochs, loss_epoch, time_end - time_start)
    )
    writer.add_scalar('Loss', loss_epoch, epoch)
    
    with torch.no_grad():
        res = evaluator.top_k_evaluation(D, [3,5,10])    
        ndcg3, precision3, hit3, map3, mrr3 = res[0]
        ndcg5, precision5, hit5, map5, mrr5 = res[1]
        ndcg10, precision10, hit10, map10, mrr10 = res[2]
        writer.add_scalar('Metrics/NDCG@3', ndcg3, epoch)
        writer.add_scalar('Metrics/NDCG@5', ndcg5, epoch)
        writer.add_scalar('Metrics/NDCG@10', ndcg10, epoch)
        writer.add_scalar('Metrics/Precision@3', precision3, epoch)
        writer.add_scalar('Metrics/Precision@5', precision5, epoch)
        writer.add_scalar('Metrics/Precision@10', precision10, epoch)
        writer.add_scalar('Metrics/Hit@3', hit3, epoch)
        writer.add_scalar('Metrics/Hit@5', hit5, epoch)
        writer.add_scalar('Metrics/Hit@10', hit10, epoch)
        writer.add_scalar('Metrics/MAP', map10, epoch)
        writer.add_scalar('Metrics/MRR', mrr10, epoch)
        
        if(precision10 > best_p):
            best_p = precision10
            best_epoch = epoch
            bad_counter = 0
            torch.save(D.state_dict(),"./pretrained_models/pretrained_model_sns.pkl")
        else:
            bad_counter += 1   
            
        if bad_counter == patience:
            break
    time_epoch_end = time.time()
writer.close()
# Out:
# 	[Discriminator][Epochs 1/200] [D epoch loss: 0.68244] [Time:2.12873]
# 	[Discriminator][Epochs 2/200] [D epoch loss: 0.66134] [Time:2.43261]
# 	[Discriminator][Epochs 3/200] [D epoch loss: 0.64027] [Time:2.27455]
# 	[Discriminator][Epochs 4/200] [D epoch loss: 0.61851] [Time:2.35460]
# 	[Discriminator][Epochs 5/200] [D epoch loss: 0.59687] [Time:2.29360]
# 	[Discriminator][Epochs 6/200] [D epoch loss: 0.57810] [Time:2.14305]
# 	[Discriminator][Epochs 7/200] [D epoch loss: 0.56323] [Time:2.16312]
# 	[Discriminator][Epochs 8/200] [D epoch loss: 0.55216] [Time:2.40571]
# 	[Discriminator][Epochs 9/200] [D epoch loss: 0.54220] [Time:2.37356]
# 	[Discriminator][Epochs 10/200] [D epoch loss: 0.53450] [Time:2.18632]
# 	[Discriminator][Epochs 11/200] [D epoch loss: 0.52865] [Time:2.23099]
# 	[Discriminator][Epochs 12/200] [D epoch loss: 0.52408] [Time:2.05657]
# 	[Discriminator][Epochs 13/200] [D epoch loss: 0.51952] [Time:2.13023]
# 	[Discriminator][Epochs 14/200] [D epoch loss: 0.51717] [Time:2.15012]
# 	[Discriminator][Epochs 15/200] [D epoch loss: 0.51540] [Time:2.05803]
# 	[Discriminator][Epochs 16/200] [D epoch loss: 0.51193] [Time:2.18975]
# 	[Discriminator][Epochs 17/200] [D epoch loss: 0.51046] [Time:2.05139]
# 	[Discriminator][Epochs 18/200] [D epoch loss: 0.50968] [Time:2.41149]
# 	[Discriminator][Epochs 19/200] [D epoch loss: 0.50978] [Time:2.27118]
# 	[Discriminator][Epochs 20/200] [D epoch loss: 0.50676] [Time:2.13982]
# 	[Discriminator][Epochs 21/200] [D epoch loss: 0.50659] [Time:2.38102]
# 	[Discriminator][Epochs 22/200] [D epoch loss: 0.50589] [Time:2.05218]
# 	[Discriminator][Epochs 23/200] [D epoch loss: 0.50524] [Time:2.32920]
# 	[Discriminator][Epochs 24/200] [D epoch loss: 0.50603] [Time:2.24736]
# 	[Discriminator][Epochs 25/200] [D epoch loss: 0.50390] [Time:2.41646]
# 	[Discriminator][Epochs 26/200] [D epoch loss: 0.50389] [Time:2.42124]
# 	[Discriminator][Epochs 27/200] [D epoch loss: 0.50382] [Time:2.26766]
# 	[Discriminator][Epochs 28/200] [D epoch loss: 0.50268] [Time:2.45519]
# 	[Discriminator][Epochs 29/200] [D epoch loss: 0.50165] [Time:2.40729]
# 	[Discriminator][Epochs 30/200] [D epoch loss: 0.50099] [Time:2.43728]
# 	[Discriminator][Epochs 31/200] [D epoch loss: 0.50152] [Time:2.17560]
# 	[Discriminator][Epochs 134/200] [D epoch loss: 0.46656] [Time:2.54303]
# 	[Discriminator][Epochs 135/200] [D epoch loss: 0.46676] [Time:2.54903]
# 	[Discriminator][Epochs 136/200] [D epoch loss: 0.46681] [Time:2.47124]
# 	[Discriminator][Epochs 137/200] [D epoch loss: 0.46586] [Time:2.02269]
# 	[Discriminator][Epochs 138/200] [D epoch loss: 0.46646] [Time:2.54996]
# 	[Discriminator][Epochs 139/200] [D epoch loss: 0.46585] [Time:2.53478]
# 	[Discriminator][Epochs 140/200] [D epoch loss: 0.46499] [Time:2.42447]
# 	[Discriminator][Epochs 141/200] [D epoch loss: 0.46606] [Time:2.53383]
# 	[Discriminator][Epochs 142/200] [D epoch loss: 0.46493] [Time:2.54308]
# 	[Discriminator][Epochs 143/200] [D epoch loss: 0.46518] [Time:2.20175]
# 	[Discriminator][Epochs 144/200] [D epoch loss: 0.46534] [Time:2.12845]
# 	[Discriminator][Epochs 145/200] [D epoch loss: 0.46487] [Time:2.53581]
# 	[Discriminator][Epochs 146/200] [D epoch loss: 0.46517] [Time:2.53531]
# 	[Discriminator][Epochs 147/200] [D epoch loss: 0.46589] [Time:2.31624]
# 	[Discriminator][Epochs 148/200] [D epoch loss: 0.46490] [Time:2.54421]
# 	[Discriminator][Epochs 149/200] [D epoch loss: 0.46595] [Time:2.57177]
# 	[Discriminator][Epochs 150/200] [D epoch loss: 0.46466] [Time:2.54200]
# 	[Discriminator][Epochs 151/200] [D epoch loss: 0.46433] [Time:2.17534]
# 	[Discriminator][Epochs 152/200] [D epoch loss: 0.46580] [Time:2.53884]
# 	[Discriminator][Epochs 153/200] [D epoch loss: 0.46401] [Time:2.52997]
# 	[Discriminator][Epochs 154/200] [D epoch loss: 0.46465] [Time:2.53012]
# 	[Discriminator][Epochs 155/200] [D epoch loss: 0.46438] [Time:2.52448]
# 	[Discriminator][Epochs 156/200] [D epoch loss: 0.46463] [Time:2.32977]
# 	[Discriminator][Epochs 157/200] [D epoch loss: 0.46370] [Time:2.54599]
# 	[Discriminator][Epochs 158/200] [D epoch loss: 0.46412] [Time:2.19228]
# 	[Discriminator][Epochs 159/200] [D epoch loss: 0.46485] [Time:2.55472]
# 	[Discriminator][Epochs 160/200] [D epoch loss: 0.46481] [Time:2.53856]
# 	[Discriminator][Epochs 161/200] [D epoch loss: 0.46328] [Time:2.55146]
# 	[Discriminator][Epochs 162/200] [D epoch loss: 0.46406] [Time:2.54428]
# 	[Discriminator][Epochs 163/200] [D epoch loss: 0.46289] [Time:2.53672]
# 	[Discriminator][Epochs 164/200] [D epoch loss: 0.46244] [Time:2.56498]
# 	[Discriminator][Epochs 165/200] [D epoch loss: 0.46335] [Time:2.54232]
# 	[Discriminator][Epochs 166/200] [D epoch loss: 0.46279] [Time:2.37425]
# 	[Discriminator][Epochs 167/200] [D epoch loss: 0.46482] [Time:2.15973]
# 	[Discriminator][Epochs 168/200] [D epoch loss: 0.46302] [Time:2.55423]
# 	[Discriminator][Epochs 169/200] [D epoch loss: 0.46376] [Time:2.26179]
# 	[Discriminator][Epochs 170/200] [D epoch loss: 0.46332] [Time:2.48689]
# 	[Discriminator][Epochs 171/200] [D epoch loss: 0.46293] [Time:2.14466]
# 	[Discriminator][Epochs 172/200] [D epoch loss: 0.46366] [Time:2.28740]
# 	[Discriminator][Epochs 173/200] [D epoch loss: 0.46269] [Time:2.49966]
# 	[Discriminator][Epochs 174/200] [D epoch loss: 0.46321] [Time:2.50196]
# 	[Discriminator][Epochs 175/200] [D epoch loss: 0.46157] [Time:2.08207]
# 	[Discriminator][Epochs 176/200] [D epoch loss: 0.46245] [Time:2.14729]
# 	[Discriminator][Epochs 177/200] [D epoch loss: 0.46174] [Time:2.52973]
# 	[Discriminator][Epochs 178/200] [D epoch loss: 0.46264] [Time:2.36788]
# 	[Discriminator][Epochs 179/200] [D epoch loss: 0.46242] [Time:2.35221]
# 	[Discriminator][Epochs 180/200] [D epoch loss: 0.46233] [Time:2.51439]
# 	[Discriminator][Epochs 181/200] [D epoch loss: 0.46289] [Time:2.51445]
# 	[Discriminator][Epochs 182/200] [D epoch loss: 0.46101] [Time:2.23075]
# 	[Discriminator][Epochs 183/200] [D epoch loss: 0.46177] [Time:2.50234]
# 	[Discriminator][Epochs 184/200] [D epoch loss: 0.46186] [Time:2.54074]
# 	[Discriminator][Epochs 185/200] [D epoch loss: 0.46085] [Time:2.25306]
# 	[Discriminator][Epochs 186/200] [D epoch loss: 0.46072] [Time:2.14267]
# 	[Discriminator][Epochs 187/200] [D epoch loss: 0.46248] [Time:2.54181]
# 	[Discriminator][Epochs 188/200] [D epoch loss: 0.46063] [Time:2.49004]
# 	[Discriminator][Epochs 189/200] [D epoch loss: 0.46139] [Time:2.10617]
# 	[Discriminator][Epochs 190/200] [D epoch loss: 0.46133] [Time:2.51109]
# 	[Discriminator][Epochs 191/200] [D epoch loss: 0.46148] [Time:2.50269]
# 	[Discriminator][Epochs 192/200] [D epoch loss: 0.46040] [Time:2.34133]
# 	[Discriminator][Epochs 193/200] [D epoch loss: 0.46003] [Time:2.14621]
# 	[Discriminator][Epochs 194/200] [D epoch loss: 0.46009] [Time:2.11892]
# 	[Discriminator][Epochs 195/200] [D epoch loss: 0.46118] [Time:2.11777]
# 	[Discriminator][Epochs 196/200] [D epoch loss: 0.46015] [Time:2.51442]
# 	[Discriminator][Epochs 197/200] [D epoch loss: 0.46078] [Time:2.53261]
# 	[Discriminator][Epochs 198/200] [D epoch loss: 0.45987] [Time:2.52874]
# 	[Discriminator][Epochs 199/200] [D epoch loss: 0.45927] [Time:2.41809]
# 	[Discriminator][Epochs 200/200] [D epoch loss: 0.46038] [Time:2.51915]

# %%
print(best_epoch)
D.load_state_dict(torch.load("./pretrained_models/pretrained_model_sns.pkl"))
# Out:
# 199
# <All keys matched successfully>
